# %%
import pandas as pd
# Out:
# /Users/Corman/GA/Projects/racechart/.env/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
drivers = pd.read_csv('./racechart_folder/racechart/json/csv/drivers.csv', error_bad_lines=False)
# Out:
# b'Skipping line 8: expected 17 fields, saw 18\nSkipping line 23: expected 17 fields, saw 18\nSkipping line 34: expected 17 fields, saw 18\nSkipping line 36: expected 17 fields, saw 18\nSkipping line 40: expected 17 fields, saw 19\nSkipping line 43: expected 17 fields, saw 18\nSkipping line 44: expected 17 fields, saw 18\nSkipping line 46: expected 17 fields, saw 19\nSkipping line 57: expected 17 fields, saw 18\nSkipping line 58: expected 17 fields, saw 19\nSkipping line 59: expected 17 fields, saw 19\n'

# %%
drivers.head()
# Out:
#                                      id first_name   last_name  \
# 0  25884070-3ded-4fdc-9370-d09428ac95e4      David       Ragan
# 1  3ebef96f-43b4-422a-9d0c-db0127b25384       Alex      Bowman
# 2  c9bf58a8-66b6-4d75-a441-c13130ded990    William       Byron
# 3  25cfebb6-24e5-429c-a9db-c276bab0e228      Chris    Buescher
# 4  46f77b78-961b-48cc-8681-b971511d2d5e       D.J.  Kennington
#
#          full_name      height    birthday rookie_year gender         status  \
# 0      David Ragan          72  1985-12-24        2007      M            ACT
# 1      Alex Bowman  1993-04-25        2013           M    ACT  UNITED STATES
# 2    William Byron  1997-11-29        2016           M    ACT  UNITED STATES
# 3   Chris Buescher  1992-10-29        2014           M    ACT  UNITED STATES
# 4  D.J. Kennington          70  1977-07-15           M    ACT         CANADA
#
#          country                                    residence  \
# ...

# %%
drivers.shape
# Out:
# (48, 17)

# %%
drivers.head(48)
# Out:
#                                       id first_name     last_name  \
# 0   25884070-3ded-4fdc-9370-d09428ac95e4      David         Ragan
# 1   3ebef96f-43b4-422a-9d0c-db0127b25384       Alex        Bowman
# 2   c9bf58a8-66b6-4d75-a441-c13130ded990    William         Byron
# 3   25cfebb6-24e5-429c-a9db-c276bab0e228      Chris      Buescher
# 4   46f77b78-961b-48cc-8681-b971511d2d5e       D.J.    Kennington
# 5   262c7b0f-fab8-4d5e-854c-7d54d039b994     Danica       Patrick
# 6   67948099-4196-4e1b-ae9e-b437aa99000a       Ryan        Blaney
# 7   0cdae85e-0b1d-44d7-9614-a49aff66aeb5      Ricky     Stenhouse
# 8   ebd0a08d-5308-442e-a2ae-2e40aafb3100     Daniel        Suarez
# 9   06c9c0f9-392a-4f0e-aae7-39bb417af02f       Matt   DiBenedetto
# 10  cb9d6f49-0044-4305-be9a-22d428e52c95      Denny        Hamlin
# 11  939e647d-756f-41d7-ad65-609344f64bd5      Bubba       Wallace
# 12  2db0c428-bdbc-4404-abe5-e804488c36b8    Derrike          Cope
# ...
